# %% [markdown]
# # Module 04 - Lesson 01 Review

# %%
import pandas as pd

df = pd.DataFrame({'Values': [180.5, 178.8, 176.2, 177.1, 178.75, 179.25, 175.4, 178.2, 177.25, 177.5, 
                              179.9, 180.8, 177.75, 179.5, 179.25, 178.5, 178.8, 178.5, 176.5, 178.76,
                              181.6]})

print(df['Values'].mean())
print(df['Values'].median())
print(df['Values'].std())

# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.stats as stats


values = df['Values']
density = stats.gaussian_kde(values)
n, x, _ = plt.hist(values, histtype='step', density=True)  
plt.plot(x, density(x)*21)
plt.axvline(values.mean(), color='magenta', linestyle='dashed', linewidth=2)
plt.axvline(values.median(), color='green', linestyle='dashed', linewidth=2)
plt.show()
# Out:
# 178.5147619047619
# 178.75
# 1.5389204626868134

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'Values': [172,174,176,172,172,173,176,172,177,174,176,175,176,169,175,174,174,174,175,173,
                              171,171,175,175,173,175,175]})


print("Count: " + str(len(df)))
print("Mean: " + str(df['Values'].mean()))
print("Median: " + str(df['Values'].median()))
print("Mode: " + str(df['Values'].mode()))
print("Standard Dev: " + str(df['Values'].std()))
print(df['Values'].describe())

# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.stats as stats


values = df['Values']
density = stats.gaussian_kde(values)
n, x, _ = plt.hist(values, histtype='step', density=True)  
plt.plot(x, density(x)*21)
plt.axvline(values.mean(), color='magenta', linestyle='dashed', linewidth=2)
plt.axvline(values.median(), color='green', linestyle='dashed', linewidth=2)
plt.show()
# Out:
# Count: 27
# Mean: 173.85185185185185
# Median: 174.0
# Mode: 0    175
# dtype: int64
# Standard Dev: 1.8954135676924426
# count     27.000000
# mean     173.851852
# std        1.895414
# min      169.000000
# 25%      172.500000
# 50%      174.000000
# 75%      175.000000
# max      177.000000
# Name: Values, dtype: float64

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'Values': [184,180,181,184,182,181,182,182,183,182,181,182,182,180,
                              183,181,184,183,182,182,183,182,183,181,180,181,183]})


print("Count: " + str(len(df)))
print("Mean: " + str(df['Values'].mean()))
print("Median: " + str(df['Values'].median()))
print("Mode: " + str(df['Values'].mode()))
print("Standard Dev: " + str(df['Values'].std()))
print(df['Values'].describe())

# %matplotlib inline
import matplotlib.pyplot as plt
import scipy.stats as stats


values = df['Values']
density = stats.gaussian_kde(values)
n, x, _ = plt.hist(values, histtype='step', density=True)  
plt.plot(x, density(x)*21)
plt.axvline(values.mean(), color='magenta', linestyle='dashed', linewidth=2)
plt.axvline(values.median(), color='green', linestyle='dashed', linewidth=2)
plt.show()
# Out:
# Count: 27
# Mean: 182.0
# Median: 182.0
# Mode: 0    182
# dtype: int64
# Standard Dev: 1.1766968108291043
# count     27.000000
# mean     182.000000
# std        1.176697
# min      180.000000
# 25%      181.000000
# 50%      182.000000
# 75%      183.000000
# max      184.000000
# Name: Values, dtype: float64

# %%
# %matplotlib inline
from scipy.stats import binom
from matplotlib import pyplot as plt
import numpy as np

n = 3
p = 0.1
x = np.array(range(0, n+1))

print(binom.pmf(2, n, p))

prob = np.array([binom.pmf(k, n, p) for k in x])

# Set up the graph
plt.xlabel('x')
plt.ylabel('Probability')
plt.bar(x, prob)
plt.show()
# Out:
# 0.027000000000000007
